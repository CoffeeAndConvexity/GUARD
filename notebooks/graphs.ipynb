# %%
import os
import sys
sys.path.append('..')
from graphs.graph_generation import GraphGenerator

# %%
from graphs.graph_generation import GraphGenerator
gg = GraphGenerator()
gg.generate_simplified_graph("Soho, NY, USA", show=True)
