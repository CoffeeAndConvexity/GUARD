# %%
import pandas as pd

# %%
ido = pd.read_csv("ISG_SF_DO_MASS_FINAL.csv")

# %%
ido[(ido["num_timesteps"]<=10) & (ido["iteration_number"]==1)]
# Out:
#      Unnamed: 0  num_timesteps  num_defenders  defense_time_threshold  \
# 0             0              7              1                       1
# 6             6              7              1                       2
# 10           10              7              2                       1
# 21           21              7              2                       2
# 25           25              7              3                       1
# 53           53              7              3                       2
# 57           57              8              1                       1
# 63           63              8              1                       2
# 69           69              8              2                       1
# 79           79              8              2                       2
# 89           89              8              3                       1
# 113         113              8              3                       2
# ...

# %% [markdown]
# ido

# %%
ido
# Out:
#       Unnamed: 0  num_timesteps  num_attackers  num_defenders  force_return  \
# 0              0              7              1              1          True
# 1              1              7              1              1          True
# 2              2              7              1              1          True
# 3              3              7              1              1          True
# 4              4              7              1              1          True
# ...          ...            ...            ...            ...           ...
# 2837        2837             11              3              3         False
# 2838        2838             11              3              3         False
# 2839        2839             11              3              3         False
# 2840        2840             11              3              3         False
# 2841        2841             11              3              3         False
#
# ...

# %%
gdo = pd.read_csv("GSG_NFG_DO_MASS_FINAL.csv")

# %%
gdo[(gdo["num_timesteps"]==8) & (gdo["num_attackers"]==1) & (gdo["num_defenders"]==1) & (gdo["num_clusters"]==10) & (gdo["dims"]==7) & (gdo["defense_time_threshold"]==1) & (gdo["iteration_number"]==1)]
# Out:
#       Unnamed: 0  num_timesteps  num_attackers  num_defenders  num_clusters  \
# 8693        8693              8              1              1            10
# 8700        8700              8              1              1            10
#
#       dims  force_return  defense_time_threshold  iteration_number  \
# 8693     7          True                       1                 1
# 8700     7         False                       1                 1
#
#       iteration_time       gap  iterations_to_converge  def_support  \
# 8693        0.013503  0.842657                       7            4
# 8700        0.011762  0.842657                      13            6
#
#       defender_actions_size  attacker_actions_size
# 8693                      6                      5
# 8700                     10                      6
